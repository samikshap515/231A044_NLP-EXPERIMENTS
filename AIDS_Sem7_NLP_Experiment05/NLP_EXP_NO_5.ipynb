# %% [markdown]
# <a href="https://colab.research.google.com/github/samikshap515/231A044_NLP-EXPERIMENTS/blob/main/AIDS_Sem7_NLP_Experiment05/NLP_EXP_NO_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Samiksha Patil", "UIN: 231A044\n")
import nltk
from nltk import word_tokenize, bigrams, FreqDist, ConditionalFreqDist
from nltk.corpus import stopwords
from collections import defaultdict
# Out:
# Samiksha Patil UIN: 231A044

# %%
print("Samiksha Patil", "UIN: 231A044\n")
# Download necessary NLTK resources
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('punkt_tab')
# Out:
# Samiksha Patil UIN: 231A044
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
print("Samiksha Patil", "UIN: 231A044\n")
# Step 1: Load and preprocess the text corpus
def preprocess(text):
    # Convert to lowercase
    text = text.lower()

    # Tokenize the text
    tokens = word_tokenize(text)

    # Remove punctuation and stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [token for token in tokens if token.isalnum() and token not in stop_words]
    return tokens

# Sample text corpus
corpus = "The quick brown fox jumps over the lazy dog. The fox is quick and the dog is lazy."

# Step 2: Preprocess the text
tokens = preprocess(corpus)
print(tokens)
# Out:
# Samiksha Patil UIN: 231A044
#
# ['quick', 'brown', 'fox', 'jumps', 'lazy', 'dog', 'fox', 'quick', 'dog', 'lazy']

# %%
print("Samiksha Patil", "UIN: 231A044\n")
# Step 3: Generate bigrams from the tokenized text
bigrams_list = list(bigrams(tokens))
print(bigrams_list)
# Out:
# Samiksha Patil UIN: 231A044
#
# [('quick', 'brown'), ('brown', 'fox'), ('fox', 'jumps'), ('jumps', 'lazy'), ('lazy', 'dog'), ('dog', 'fox'), ('fox', 'quick'), ('quick', 'dog'), ('dog', 'lazy')]

# %%
print("Samiksha Patil", "UIN: 231A044\n")

# Step 4: Count bigram frequencies using FreqDist
bigram_freq = FreqDist(bigrams_list)
bigram_freq
# Out:
# Samiksha Patil UIN: 231A044
# FreqDist({('quick', 'brown'): 1, ('brown', 'fox'): 1, ('fox', 'jumps'): 1, ('jumps', 'lazy'): 1, ('lazy', 'dog'): 1, ('dog', 'fox'): 1, ('fox', 'quick'): 1, ('quick', 'dog'): 1, ('dog', 'lazy'): 1})

# %%
print("Samiksha Patil", "UIN: 231A044\n")
cfd = ConditionalFreqDist(bigrams_list)
cfd.items()
# Out:
# Samiksha Patil UIN: 231A044
# dict_items([('quick', FreqDist({'brown': 1, 'dog': 1})), ('brown', FreqDist({'fox': 1})), ('fox', FreqDist({'jumps': 1, 'quick': 1})), ('jumps', FreqDist({'lazy': 1})), ('lazy', FreqDist({'dog': 1})), ('dog', FreqDist({'fox': 1, 'lazy': 1}))])

# %%
print("Samiksha Patil", "UIN: 231A044\n")
cfd.keys()
# Out:
# Samiksha Patil UIN: 231A044
# dict_keys(['quick', 'brown', 'fox', 'jumps', 'lazy', 'dog'])

# %%
print("Samiksha Patil", "UIN: 231A044\n")
from nltk import trigrams

trigrams_list = list(trigrams(tokens))
print(trigrams_list)
# Out:
# Samiksha Patil UIN: 231A044
#
# [('quick', 'brown', 'fox'), ('brown', 'fox', 'jumps'), ('fox', 'jumps', 'lazy'), ('jumps', 'lazy', 'dog'), ('lazy', 'dog', 'fox'), ('dog', 'fox', 'quick'), ('fox', 'quick', 'dog'), ('quick', 'dog', 'lazy')]

# %%
print("Samiksha Patil", "UIN: 231A044\n")
trigram_freq = FreqDist(trigrams_list)
trigram_freq
# Out:
# Samiksha Patil UIN: 231A044
# FreqDist({('quick', 'brown', 'fox'): 1, ('brown', 'fox', 'jumps'): 1, ('fox', 'jumps', 'lazy'): 1, ('jumps', 'lazy', 'dog'): 1, ('lazy', 'dog', 'fox'): 1, ('dog', 'fox', 'quick'): 1, ('fox', 'quick', 'dog'): 1, ('quick', 'dog', 'lazy'): 1})

# %%
print("Samiksha Patil", "UIN: 231A044\n")
# Step 6: Function to predict the next word based on a given word
def predict_next_word(word):
    word = word.lower()
    if word in cfd:
        next_word = cfd[word].max()  # Get the most likely word following the given word
        return next_word
    else:
        return None
# Out:
# Samiksha Patil UIN: 231A044

# %%
print("Samiksha Patil", "UIN: 231A044\n")
# Test the prediction function
start_word = "fox"
predicted_word = predict_next_word(start_word)

if predicted_word:
    print(f"Next word after '{start_word}': '{predicted_word}'")
else:
    print(f"No prediction available for the word '{start_word}'.")
# Out:
# Samiksha Patil UIN: 231A044
#
# Next word after 'fox': 'jumps'

# %%
print("Samiksha Patil", "UIN: 231A044\n")
# Step 7: Generate a sequence of words
def generate_sequence(start_word, length=8):
    sequence = [start_word]
    current_word = start_word

    for _ in range(length):
        next_word = predict_next_word(current_word)

        if next_word:
            sequence.append(next_word)
            current_word = next_word
        else:
            break

    return ' '.join(sequence)


# Generate a sequence starting from "the"
generated_sequence = generate_sequence("jumps", length=8)
print(f"Generated sequence: {generated_sequence}")
# Out:
# Samiksha Patil UIN: 231A044
#
# Generated sequence: jumps lazy dog fox jumps lazy dog fox jumps

# %%
print("Samiksha Patil", "UIN: 231A044\n")
import nltk
from nltk import bigrams,trigrams,ngrams
from nltk.corpus import reuters
from collections import defaultdict
# Out:
# Samiksha Patil UIN: 231A044

# %%
print("Samiksha Patil", "UIN: 231A044\n")
nltk.download('reuters')
nltk.download('punkt')
# Out:
# Samiksha Patil UIN: 231A044
# [nltk_data] Downloading package reuters to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
print("Samiksha Patil", "UIN: 231A044\n")
# Visualizing the corpus

# List of file IDs in the corpus
file_ids = reuters.fileids()

print(file_ids[:100])  # Print the first 100 file IDs
# Out:
# Samiksha Patil UIN: 231A044
#
# ...

# %%
print("Samiksha Patil", "UIN: 231A044\n")
len(file_ids)
# Out:
# Samiksha Patil UIN: 231A044
# 10788

# %%
print("Samiksha Patil", "UIN: 231A044\n")
print(reuters.words()[:60])
# Out:
# Samiksha Patil UIN: 231A044
#
# ['ASIAN', 'EXPORTERS', 'FEAR', 'DAMAGE', 'FROM', 'U', '.', 'S', '.-', 'JAPAN', 'RIFT', 'Mounting', 'trade', 'friction', 'between', 'the', 'U', '.', 'S', '.', 'And', 'Japan', 'has', 'raised', 'fears', 'among', 'many', 'of', 'Asia', "'", 's', 'exporting', 'nations', 'that', 'the', 'row', 'could', 'inflict', 'far', '-', 'reaching', 'economic', 'damage', ',', 'businessmen', 'and', 'officials', 'said', '.', 'They', 'told', 'Reuter', 'correspondents', 'in', 'Asian', 'capitals', 'a', 'U', '.', 'S']

# %%
print("Samiksha Patil", "UIN: 231A044\n")
word1 = reuters.words(file_ids)
len(word1)
# Out:
# Samiksha Patil UIN: 231A044
# 1720901

# %%
print("Samiksha Patil", "UIN: 231A044\n")
# Extract words or sentences from file id:<any index location>
words = reuters.words(file_ids[10787])
print(words[:200])  # Print the first 200 words of the article
# Out:
# Samiksha Patil UIN: 231A044
#
# ['&', 'lt', ';', 'A', '.', 'H', '.', 'A', '.', 'AUTOMOTIVE', 'TECHNOLOGIES', 'CORP', '>', 'YEAR', 'NET', 'Shr', '43', 'cts', 'vs', '52', 'cts', 'Shr', 'diluted', '41', 'cts', 'vs', '49', 'cts', 'Net', '1', ',', '916', ',', '000', 'vs', '2', ',', '281', ',', '000', 'Revs', '32', '.', '6', 'mln', 'vs', '22', '.', '6', 'mln']

# %%
print("Samiksha Patil", "UIN: 231A044\n")
words = nltk.word_tokenize(" ".join(reuters.words()))
# Out:
# Samiksha Patil UIN: 231A044

# %%
print("Samiksha Patil", "UIN: 231A044\n")
len(words)
# Out:
# Samiksha Patil UIN: 231A044
# 1728932

# %%
print("Samiksha Patil", "UIN: 231A044\n")
tri_grams = list(trigrams(words))
print(tri_grams[:10000])
# Out:
# Samiksha Patil UIN: 231A044
#
# ...

# %%
print("Samiksha Patil", "UIN: 231A044\n")
model = defaultdict(lambda: defaultdict(lambda: 0))
# Out:
# Samiksha Patil UIN: 231A044

# %%
print("Samiksha Patil", "UIN: 231A044\n")
for w1, w2, w3 in tri_grams:
    model[(w1, w2)][w3] += 1
# Out:
# Samiksha Patil UIN: 231A044

# %%
print("Samiksha Patil", "UIN: 231A044\n")
# Transform the counts into probabilities
for w1,w2 in model:
    total_count = float(sum(model[w1,w2].values()))
    for w3 in model[w1,w2]:
        model[w1,w2][w3] /= total_count
# Out:
# Samiksha Patil UIN: 231A044

# %%
print("Samiksha Patil", "UIN: 231A044\n")
# Function to predict the next word
def predict_next_word(w1, w2):
    next_word = model[w1, w2]
    if next_word:
        predicted_word = max(next_word, key=next_word.get)
        # Choose the most likely next word
        return predicted_word
    else:
        return "No prediction available"
# Out:
# Samiksha Patil UIN: 231A044

# %%
print("Samiksha Patil", "UIN: 231A044\n")
print("Next Word:", predict_next_word('NET', 'Shr'))
# Out:
# Samiksha Patil UIN: 231A044
#
# Next Word: profit

# %%
print("Samiksha Patil", "UIN: 231A044\n")
def calculate_perplexity(test_text, ngram_probs):

    n = len(words)
    log_prob_sum = 0

    # Calculate the log probabilities of the trigrams in the test text
    for i in range(len(tokens) - 1):
        w1, w2 = tokens[i], tokens[i + 1]
        prob = model[w1][w2] if w2 in model[w1] else 1e-6  # Handle unseen bigrams with a very small val...
        log_prob_sum += math.log(prob)

    # Calculate perplexity
    perplexity = math.exp(-log_prob_sum / (n - 1))
    return perplexity
# Out:
# Samiksha Patil UIN: 231A044

# %%
print("Samiksha Patil", "UIN: 231A044\n")
import math
from nltk import word_tokenize

words = "asian exporters fear damage"
tokens = word_tokenize(words)
# Out:
# Samiksha Patil UIN: 231A044

# %%
print("Samiksha Patil", "UIN: 231A044\n")
calculate_perplexity(words, model)
# Out:
# Samiksha Patil UIN: 231A044
# 4.923882631706739

# %%
print("Samiksha Patil", "UIN: 231A044\n")
print(reuters.raw('test/15027'))
# Out:
# Samiksha Patil UIN: 231A044
#
# FIRSTBANC CORP OF OHIO &lt;FBOH> 1ST QTR NET
#   Shr 74 cts vs 67 cts
#       Net 8,067,000 vs 7,317,000

# %%
print("Samiksha Patil", "UIN: 231A044\n")
# Out:
# Samiksha Patil UIN: 231A044

# %%
print("Samiksha Patil", "UIN: 231A044\n")
# Out:
# Samiksha Patil UIN: 231A044
